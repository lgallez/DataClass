# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

units = "imperial"

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 603

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5bc334e636ace5c374e5116f1c34e907"

city_weather_final = []
record_count = 1
set_count = 1

print("-----------------------")
print("Start of Data Retrieval")
print("-----------------------")

for city in cities:
    city_url = url + "&q=" + city
    
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    
    record_count += 1
    city_weather = requests.get(city_url).json()

    if '404' in city_weather.values():
        print("City not found. Skipping...")
        continue
    
        
    city_lat = city_weather["coord"]["lat"]
    city_lng = city_weather["coord"]["lon"]
    city_max_temp = city_weather["main"]["temp_max"]
    city_humidity = city_weather["main"]["humidity"]
    city_clouds = city_weather["clouds"]["all"]
    city_wind = city_weather["wind"]["speed"]
    city_country = city_weather["sys"]["country"]
    city_date = city_weather["dt"]
   

    city_weather_final.append({"City": city,
                      "Lat": city_lat,
                      "Lng": city_lng,
                      "Max Temp": city_max_temp,
                      "Humidity": city_humidity,
                      "Cloudiness": city_clouds,
                      "Wind Speed": city_wind,
                      "Country": city_country,
                      "Date": city_date
                      })
    
print("---------------------")
print("End of Data Retrieval")
print("---------------------")
# Out:
# -----------------------
# Start of Data Retrieval
# -----------------------
# Processing Record 1 of Set 1 | ponta do sol
# Processing Record 2 of Set 1 | freeport
# Processing Record 3 of Set 1 | bay roberts
# Processing Record 4 of Set 1 | chokurdakh
# Processing Record 5 of Set 1 | minna
# Processing Record 6 of Set 1 | tura
# Processing Record 7 of Set 1 | pryazha
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 1 | coronel bogado
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | mandawar
# Processing Record 15 of Set 1 | xining
# Processing Record 16 of Set 1 | norman wells
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | roald
# Processing Record 20 of Set 1 | kostomuksha
# Processing Record 21 of Set 1 | la ronge
# Processing Record 22 of Set 1 | khatanga
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 1 | pankrushikha
# Processing Record 26 of Set 1 | kutum
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | honningsvag
# Processing Record 29 of Set 1 | kahului
# Processing Record 30 of Set 1 | karratha
# Processing Record 31 of Set 1 | korla
# City not found. Skipping...
# Processing Record 32 of Set 1 | butaritari
# Processing Record 33 of Set 1 | mecca
# Processing Record 34 of Set 1 | bilibino
# Processing Record 35 of Set 1 | adrar
# Processing Record 36 of Set 1 | dongsheng
# Processing Record 37 of Set 1 | along
# Processing Record 38 of Set 1 | sinnamary
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | moose factory
# Processing Record 41 of Set 1 | cabo san lucas
# Processing Record 42 of Set 1 | usinsk
# Processing Record 43 of Set 1 | puerto ayora
# Processing Record 44 of Set 1 | mizpe ramon
# City not found. Skipping...
# Processing Record 45 of Set 1 | puerto del rosario
# Processing Record 46 of Set 1 | genhe
# Processing Record 47 of Set 1 | komsomolskiy
# Processing Record 48 of Set 1 | plouzane
# Processing Record 49 of Set 1 | constitucion
# Processing Record 50 of Set 1 | vaini
# Processing Record 51 of Set 1 | jamestown
# Processing Record 52 of Set 1 | nikolskoye
# Processing Record 53 of Set 1 | qaanaaq
# Processing Record 54 of Set 1 | coquimbo
# Processing Record 55 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 56 of Set 1 | kon tum
# Processing Record 57 of Set 1 | port alfred
# Processing Record 58 of Set 1 | dikson
# Processing Record 59 of Set 1 | suhbaatar
# Processing Record 60 of Set 1 | solton
# Processing Record 61 of Set 1 | trairi
# Processing Record 62 of Set 1 | zheleznodorozhnyy
# Processing Record 63 of Set 1 | isla mujeres
# Processing Record 64 of Set 1 | guerrero negro
# Processing Record 65 of Set 1 | barrow
# Processing Record 66 of Set 1 | hasaki
# Processing Record 67 of Set 1 | vila velha
# Processing Record 68 of Set 1 | yumen
# Processing Record 69 of Set 1 | albany
# Processing Record 70 of Set 1 | carnarvon
# Processing Record 71 of Set 1 | ko samui
# Processing Record 72 of Set 1 | saint george
# Processing Record 73 of Set 1 | souillac
# Processing Record 74 of Set 1 | mpanda
# Processing Record 75 of Set 1 | boke
# Processing Record 76 of Set 1 | quebec
# Processing Record 77 of Set 1 | rikitea
# Processing Record 78 of Set 1 | gaya
# Processing Record 79 of Set 1 | wajir
# Processing Record 80 of Set 1 | georgetown
# Processing Record 81 of Set 1 | hilo
# Processing Record 82 of Set 1 | kainantu
# Processing Record 83 of Set 1 | mehamn
# Processing Record 84 of Set 1 | sawtell
# Processing Record 85 of Set 1 | alta floresta
# Processing Record 86 of Set 1 | sorong
# Processing Record 87 of Set 1 | pevek
# Processing Record 88 of Set 1 | provideniya
# Processing Record 89 of Set 1 | nalut
# Processing Record 90 of Set 1 | bethel
# Processing Record 91 of Set 1 | tiksi
# Processing Record 92 of Set 1 | pangody
# Processing Record 93 of Set 1 | hermanus
# Processing Record 94 of Set 1 | new norfolk
# Processing Record 95 of Set 1 | longyearbyen
# Processing Record 96 of Set 1 | mount gambier
# Processing Record 97 of Set 1 | aklavik
# Processing Record 98 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 99 of Set 1 | salalah
# Processing Record 100 of Set 1 | letlhakeng
# Processing Record 101 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 102 of Set 1 | san patricio
# Processing Record 103 of Set 1 | luba
# Processing Record 104 of Set 1 | chopovychi
# Processing Record 105 of Set 1 | geraldton
# Processing Record 106 of Set 1 | teplyk
# Processing Record 107 of Set 1 | dunedin
# Processing Record 108 of Set 1 | isangel
# Processing Record 109 of Set 1 | alofi
# Processing Record 110 of Set 1 | likasi
# Processing Record 111 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 112 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 113 of Set 1 | okhotsk
# Processing Record 114 of Set 1 | nishihara
# Processing Record 115 of Set 1 | port elizabeth
# Processing Record 116 of Set 1 | matadi
# Processing Record 117 of Set 1 | leningradskiy
# Processing Record 118 of Set 1 | watrous
# Processing Record 119 of Set 1 | chuy
# Processing Record 120 of Set 1 | port hardy
# Processing Record 121 of Set 1 | luderitz
# Processing Record 122 of Set 1 | mahebourg
# Processing Record 123 of Set 1 | antalaha
# Processing Record 124 of Set 1 | santa lucia
# Processing Record 125 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 126 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 127 of Set 1 | kailua
# Processing Record 128 of Set 1 | kodiak
# Processing Record 129 of Set 1 | irbeyskoye
# Processing Record 130 of Set 1 | nanortalik
# Processing Record 131 of Set 1 | mangochi
# Processing Record 132 of Set 1 | sharjah
# Processing Record 133 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 134 of Set 1 | ati
# Processing Record 135 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 136 of Set 1 | airai
# Processing Record 137 of Set 1 | barbar
# City not found. Skipping...
# Processing Record 138 of Set 1 | sorland
# Processing Record 139 of Set 1 | karauzyak
# City not found. Skipping...
# Processing Record 140 of Set 1 | nueva loja
# Processing Record 141 of Set 1 | clyde river
# Processing Record 142 of Set 1 | dingle
# Processing Record 143 of Set 1 | upernavik
# Processing Record 144 of Set 1 | fortuna
# Processing Record 145 of Set 1 | kaeo
# Processing Record 146 of Set 1 | banawang
# Processing Record 147 of Set 1 | thompson
# Processing Record 148 of Set 1 | florida
# Processing Record 149 of Set 1 | sioux lookout
# Processing Record 150 of Set 1 | kavieng
# Processing Record 151 of Set 1 | cape town
# Processing Record 152 of Set 1 | streator
# Processing Record 153 of Set 1 | sola
# Processing Record 154 of Set 1 | monrovia
# Processing Record 155 of Set 1 | cururupu
# Processing Record 156 of Set 1 | elk city
# Processing Record 157 of Set 1 | riaba
# City not found. Skipping...
# Processing Record 158 of Set 1 | pontianak
# Processing Record 159 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 160 of Set 1 | pisco
# Processing Record 161 of Set 1 | makat
# Processing Record 162 of Set 1 | ramnagar
# Processing Record 163 of Set 1 | arraial do cabo
# Processing Record 164 of Set 1 | jibuti
# City not found. Skipping...
# Processing Record 165 of Set 1 | cravo norte
# Processing Record 166 of Set 1 | faanui
# Processing Record 167 of Set 1 | sao joao da barra
# Processing Record 168 of Set 1 | bahia blanca
# Processing Record 169 of Set 1 | pinega
# Processing Record 170 of Set 1 | menongue
# Processing Record 171 of Set 1 | marsa matruh
# Processing Record 172 of Set 1 | saint-philippe
# Processing Record 173 of Set 1 | saskylakh
# Processing Record 174 of Set 1 | la asuncion
# Processing Record 175 of Set 1 | erzurum
# Processing Record 176 of Set 1 | waingapu
# Processing Record 177 of Set 1 | severo-kurilsk
# Processing Record 178 of Set 1 | kavaratti
# Processing Record 179 of Set 1 | castro
# Processing Record 180 of Set 1 | kalabo
# Processing Record 181 of Set 1 | hong gai
# Processing Record 182 of Set 1 | umm lajj
# Processing Record 183 of Set 1 | yenagoa
# Processing Record 184 of Set 1 | lyubech
# Processing Record 185 of Set 1 | hithadhoo
# Processing Record 186 of Set 1 | torbay
# Processing Record 187 of Set 1 | vardo
# Processing Record 188 of Set 1 | lerwick
# Processing Record 189 of Set 1 | ferme-neuve
# Processing Record 190 of Set 1 | port hedland
# Processing Record 191 of Set 1 | codrington
# Processing Record 192 of Set 1 | yellowknife
# Processing Record 193 of Set 1 | nome
# Processing Record 194 of Set 1 | meulaboh
# Processing Record 195 of Set 1 | san ramon de la nueva oran
# Processing Record 196 of Set 1 | sao jose da coroa grande
# Processing Record 197 of Set 1 | east london
# Processing Record 198 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 199 of Set 1 | egvekinot
# Processing Record 200 of Set 1 | cap malheureux
# Processing Record 201 of Set 1 | sao filipe
# Processing Record 202 of Set 1 | mukhen
# Processing Record 203 of Set 1 | nantucket
# Processing Record 204 of Set 1 | lakes entrance
# Processing Record 205 of Set 1 | ballina
# Processing Record 206 of Set 1 | narsaq
# Processing Record 207 of Set 1 | pullman
# Processing Record 208 of Set 1 | macaboboni
# City not found. Skipping...
# Processing Record 209 of Set 1 | nyaunglebin
# Processing Record 210 of Set 1 | hamilton
# Processing Record 211 of Set 1 | flinders
# Processing Record 212 of Set 1 | lodwar
# Processing Record 213 of Set 1 | cervo
# Processing Record 214 of Set 1 | cairns
# Processing Record 215 of Set 1 | bengkulu
# City not found. Skipping...
# Processing Record 216 of Set 1 | haverhill
# Processing Record 217 of Set 1 | ryde
# Processing Record 218 of Set 1 | poso
# Processing Record 219 of Set 1 | hovd
# Processing Record 220 of Set 1 | tamasane
# Processing Record 221 of Set 1 | jining
# Processing Record 222 of Set 1 | barranca
# Processing Record 223 of Set 1 | mocuba
# Processing Record 224 of Set 1 | preobrazheniye
# Processing Record 225 of Set 1 | cockburn town
# Processing Record 226 of Set 1 | celestun
# Processing Record 227 of Set 1 | baraganul
# Processing Record 228 of Set 1 | tambacounda
# Processing Record 229 of Set 1 | te anau
# Processing Record 230 of Set 1 | talnakh
# Processing Record 231 of Set 1 | hofn
# Processing Record 232 of Set 1 | chapais
# Processing Record 233 of Set 1 | dudinka
# Processing Record 234 of Set 1 | pandan
# Processing Record 235 of Set 1 | alice springs
# Processing Record 236 of Set 1 | kirakira
# Processing Record 237 of Set 1 | cherskiy
# Processing Record 238 of Set 1 | otjimbingwe
# Processing Record 239 of Set 1 | touros
# Processing Record 240 of Set 1 | yokadouma
# Processing Record 241 of Set 1 | jeremie
# Processing Record 242 of Set 1 | chumikan
# Processing Record 243 of Set 1 | kamenka
# Processing Record 244 of Set 1 | victoria
# Processing Record 245 of Set 1 | tasiilaq
# Processing Record 246 of Set 1 | guaraniacu
# Processing Record 247 of Set 1 | quelimane
# Processing Record 248 of Set 1 | rorvik
# Processing Record 249 of Set 1 | aykino
# Processing Record 250 of Set 1 | bathsheba
# Processing Record 251 of Set 1 | felanitx
# Processing Record 252 of Set 1 | laguna
# Processing Record 253 of Set 1 | tabas
# Processing Record 254 of Set 1 | bodden town
# Processing Record 255 of Set 1 | tuatapere
# Processing Record 256 of Set 1 | cidreira
# Processing Record 257 of Set 1 | oktyabrskiy
# Processing Record 258 of Set 1 | lorengau
# Processing Record 259 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 260 of Set 1 | ha giang
# Processing Record 261 of Set 1 | pemangkat
# City not found. Skipping...
# Processing Record 262 of Set 1 | waipawa
# Processing Record 263 of Set 1 | ketchikan
# Processing Record 264 of Set 1 | barinas
# Processing Record 265 of Set 1 | wagar
# Processing Record 266 of Set 1 | praia
# Processing Record 267 of Set 1 | necochea
# Processing Record 268 of Set 1 | santa cruz de la palma
# Processing Record 269 of Set 1 | boyabat
# Processing Record 270 of Set 1 | jalu
# Processing Record 271 of Set 1 | mar del plata
# Processing Record 272 of Set 1 | moron
# Processing Record 273 of Set 1 | ancud
# Processing Record 274 of Set 1 | grindavik
# Processing Record 275 of Set 1 | hukuntsi
# Processing Record 276 of Set 1 | novyy urengoy
# Processing Record 277 of Set 1 | morant bay
# Processing Record 278 of Set 1 | maningrida
# Processing Record 279 of Set 1 | bafq
# Processing Record 280 of Set 1 | kjollefjord
# Processing Record 281 of Set 1 | quimper
# Processing Record 282 of Set 1 | sarahan
# Processing Record 283 of Set 1 | shizunai
# Processing Record 284 of Set 1 | icatu
# Processing Record 285 of Set 1 | kupang
# Processing Record 286 of Set 1 | esperance
# Processing Record 287 of Set 1 | saldanha
# Processing Record 288 of Set 1 | doha
# Processing Record 289 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 290 of Set 1 | bilma
# Processing Record 291 of Set 1 | houma
# Processing Record 292 of Set 1 | ribeira grande
# Processing Record 293 of Set 1 | vaitape
# Processing Record 294 of Set 1 | saint albans
# Processing Record 295 of Set 1 | kuytun
# Processing Record 296 of Set 1 | solnechnyy
# Processing Record 297 of Set 1 | verkhoyansk
# Processing Record 298 of Set 1 | puerto ayacucho
# Processing Record 299 of Set 1 | kalininsk
# Processing Record 300 of Set 1 | tuktoyaktuk
# Processing Record 301 of Set 1 | babai
# Processing Record 302 of Set 1 | saint-joseph
# Processing Record 303 of Set 1 | kaitangata
# Processing Record 304 of Set 1 | port lincoln
# Processing Record 305 of Set 1 | sovetskaya gavan
# Processing Record 306 of Set 1 | cayenne
# Processing Record 307 of Set 1 | doka
# Processing Record 308 of Set 1 | lebu
# Processing Record 309 of Set 1 | mpika
# Processing Record 310 of Set 1 | namatanai
# Processing Record 311 of Set 1 | chara
# Processing Record 312 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 313 of Set 1 | camacha
# Processing Record 314 of Set 1 | bairiki
# City not found. Skipping...
# Processing Record 315 of Set 1 | porbandar
# Processing Record 316 of Set 1 | shache
# Processing Record 317 of Set 1 | envira
# City not found. Skipping...
# Processing Record 318 of Set 1 | jiayuguan
# Processing Record 319 of Set 1 | bambous virieux
# Processing Record 320 of Set 1 | cloquet
# Processing Record 321 of Set 1 | misratah
# Processing Record 322 of Set 1 | nemuro
# Processing Record 323 of Set 1 | padang
# Processing Record 324 of Set 1 | mahibadhoo
# Processing Record 325 of Set 1 | arawa
# Processing Record 326 of Set 1 | caxito
# Processing Record 327 of Set 1 | liberty
# Processing Record 328 of Set 1 | imperia
# Processing Record 329 of Set 1 | ouargaye
# Processing Record 330 of Set 1 | eskasem
# City not found. Skipping...
# Processing Record 331 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 332 of Set 1 | bredasdorp
# Processing Record 333 of Set 1 | bernalillo
# Processing Record 334 of Set 1 | ndago
# Processing Record 335 of Set 1 | klaksvik
# Processing Record 336 of Set 1 | todos santos
# Processing Record 337 of Set 1 | sao francisco de paula
# Processing Record 338 of Set 1 | port blair
# Processing Record 339 of Set 1 | avera
# Processing Record 340 of Set 1 | grand gaube
# Processing Record 341 of Set 1 | saint-georges
# Processing Record 342 of Set 1 | trincomalee
# Processing Record 343 of Set 1 | kachiry
# Processing Record 344 of Set 1 | lazarev
# Processing Record 345 of Set 1 | comodoro rivadavia
# Processing Record 346 of Set 1 | chubbuck
# Processing Record 347 of Set 1 | puyo
# Processing Record 348 of Set 1 | faya
# Processing Record 349 of Set 1 | san
# Processing Record 350 of Set 1 | buchanan
# Processing Record 351 of Set 1 | mongoumba
# Processing Record 352 of Set 1 | severo-yeniseyskiy
# Processing Record 353 of Set 1 | lompoc
# Processing Record 354 of Set 1 | katiola
# Processing Record 355 of Set 1 | tondano
# Processing Record 356 of Set 1 | maniitsoq
# Processing Record 357 of Set 1 | port-gentil
# Processing Record 358 of Set 1 | hobyo
# Processing Record 359 of Set 1 | vestmannaeyjar
# Processing Record 360 of Set 1 | broome
# Processing Record 361 of Set 1 | sassandra
# Processing Record 362 of Set 1 | kedrovyy
# Processing Record 363 of Set 1 | beringovskiy
# Processing Record 364 of Set 1 | los llanos de aridane
# Processing Record 365 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 366 of Set 1 | antonina
# Processing Record 367 of Set 1 | moranbah
# Processing Record 368 of Set 1 | lazaro cardenas
# Processing Record 369 of Set 1 | farafangana
# Processing Record 370 of Set 1 | benoy
# Processing Record 371 of Set 1 | brae
# Processing Record 372 of Set 1 | prince rupert
# Processing Record 373 of Set 1 | neiafu
# Processing Record 374 of Set 1 | simao
# Processing Record 375 of Set 1 | bobonong
# City not found. Skipping...
# Processing Record 376 of Set 1 | eggenfelden
# Processing Record 377 of Set 1 | saint anthony
# Processing Record 378 of Set 1 | auki
# Processing Record 379 of Set 1 | kruisfontein
# Processing Record 380 of Set 1 | ucluelet
# Processing Record 381 of Set 1 | the valley
# Processing Record 382 of Set 1 | bocaiuva
# Processing Record 383 of Set 1 | tsienyane
# City not found. Skipping...
# Processing Record 384 of Set 1 | bintulu
# Processing Record 385 of Set 1 | buarcos
# Processing Record 386 of Set 1 | sisimiut
# Processing Record 387 of Set 1 | yeppoon
# Processing Record 388 of Set 1 | portland
# Processing Record 389 of Set 1 | tilichiki
# Processing Record 390 of Set 1 | bantry
# City not found. Skipping...
# Processing Record 391 of Set 1 | pacifica
# Processing Record 392 of Set 1 | khandyga
# Processing Record 393 of Set 1 | chimore
# Processing Record 394 of Set 1 | sakakah
# City not found. Skipping...
# Processing Record 395 of Set 1 | merritt island
# Processing Record 396 of Set 1 | tigil
# Processing Record 397 of Set 1 | tual
# Processing Record 398 of Set 1 | tibagi
# Processing Record 399 of Set 1 | caraquet
# Processing Record 400 of Set 1 | ulma
# Processing Record 401 of Set 1 | donskoye
# Processing Record 402 of Set 1 | makakilo city
# Processing Record 403 of Set 1 | jasper
# Processing Record 404 of Set 1 | iqaluit
# Processing Record 405 of Set 1 | tahta
# City not found. Skipping...
# Processing Record 406 of Set 1 | kajaani
# Processing Record 407 of Set 1 | balangir
# Processing Record 408 of Set 1 | gamba
# Processing Record 409 of Set 1 | vicuna
# City not found. Skipping...
# Processing Record 410 of Set 1 | praia da vitoria
# Processing Record 411 of Set 1 | mujiayingzi
# Processing Record 412 of Set 1 | kangaatsiaq
# Processing Record 413 of Set 1 | puerto leguizamo
# Processing Record 414 of Set 1 | sinkat
# City not found. Skipping...
# Processing Record 415 of Set 1 | fuerte olimpo
# Processing Record 416 of Set 1 | kiruna
# Processing Record 417 of Set 1 | banjar
# Processing Record 418 of Set 1 | lagoa
# Processing Record 419 of Set 1 | sept-iles
# Processing Record 420 of Set 1 | nanakuli
# Processing Record 421 of Set 1 | kimbe
# Processing Record 422 of Set 1 | lohardaga
# Processing Record 423 of Set 1 | yar-sale
# Processing Record 424 of Set 1 | vilyuysk
# Processing Record 425 of Set 1 | maceio
# Processing Record 426 of Set 1 | progreso
# Processing Record 427 of Set 1 | shimoda
# Processing Record 428 of Set 1 | petawawa
# Processing Record 429 of Set 1 | bangangte
# Processing Record 430 of Set 1 | borama
# City not found. Skipping...
# Processing Record 431 of Set 1 | zhigansk
# Processing Record 432 of Set 1 | nautla
# Processing Record 433 of Set 1 | ekhabi
# Processing Record 434 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 435 of Set 1 | kambove
# Processing Record 436 of Set 1 | boende
# Processing Record 437 of Set 1 | oussouye
# Processing Record 438 of Set 1 | vung tau
# Processing Record 439 of Set 1 | mount abu
# Processing Record 440 of Set 1 | fereydun kenar
# Processing Record 441 of Set 1 | bubaque
# Processing Record 442 of Set 1 | lae
# Processing Record 443 of Set 1 | maldonado
# Processing Record 444 of Set 1 | vrangel
# Processing Record 445 of Set 1 | biak
# Processing Record 446 of Set 1 | blagoyevo
# Processing Record 447 of Set 1 | punuare
# Processing Record 448 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 449 of Set 1 | labuhan
# Processing Record 450 of Set 1 | lavrentiya
# Processing Record 451 of Set 1 | ferrol
# Processing Record 452 of Set 1 | kloulklubed
# Processing Record 453 of Set 1 | sur
# Processing Record 454 of Set 1 | jizan
# Processing Record 455 of Set 1 | pokhara
# Processing Record 456 of Set 1 | hami
# Processing Record 457 of Set 1 | porto novo
# Processing Record 458 of Set 1 | galiwinku
# City not found. Skipping...
# Processing Record 459 of Set 1 | saint-pierre
# Processing Record 460 of Set 1 | olafsvik
# City not found. Skipping...
# Processing Record 461 of Set 1 | nabire
# Processing Record 462 of Set 1 | one hundred mile house
# City not found. Skipping...
# Processing Record 463 of Set 1 | pangnirtung
# Processing Record 464 of Set 1 | yaroslavskiy
# Processing Record 465 of Set 1 | axim
# Processing Record 466 of Set 1 | ismailia
# Processing Record 467 of Set 1 | rochester
# Processing Record 468 of Set 1 | katsuura
# Processing Record 469 of Set 1 | santa isabel
# Processing Record 470 of Set 1 | alpena
# Processing Record 471 of Set 1 | goderich
# Processing Record 472 of Set 1 | katete
# Processing Record 473 of Set 1 | candawaga
# City not found. Skipping...
# Processing Record 474 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 475 of Set 1 | marawi
# Processing Record 476 of Set 1 | boueni
# Processing Record 477 of Set 1 | narrabri
# Processing Record 478 of Set 1 | salt
# Processing Record 479 of Set 1 | yerbogachen
# Processing Record 480 of Set 1 | oriximina
# Processing Record 481 of Set 1 | sibolga
# Processing Record 482 of Set 1 | yomitan
# City not found. Skipping...
# Processing Record 483 of Set 1 | belmonte
# Processing Record 484 of Set 1 | tasbuget
# City not found. Skipping...
# Processing Record 485 of Set 1 | gavle
# Processing Record 486 of Set 1 | alyangula
# Processing Record 487 of Set 1 | kyzyl-mazhalyk
# Processing Record 488 of Set 1 | esso
# Processing Record 489 of Set 1 | champerico
# Processing Record 490 of Set 1 | irbit
# Processing Record 491 of Set 1 | stornoway
# City not found. Skipping...
# Processing Record 492 of Set 1 | kautokeino
# Processing Record 493 of Set 1 | college
# Processing Record 494 of Set 1 | eyl
# Processing Record 495 of Set 1 | srednekolymsk
# Processing Record 496 of Set 1 | canton
# Processing Record 497 of Set 1 | ilulissat
# Processing Record 498 of Set 1 | berlevag
# Processing Record 499 of Set 1 | muriti
# Processing Record 500 of Set 1 | douglas
# Processing Record 501 of Set 1 | ormara
# Processing Record 502 of Set 1 | mineros
# Processing Record 503 of Set 1 | iralaya
# Processing Record 504 of Set 1 | klyuchi
# Processing Record 505 of Set 1 | bojnurd
# Processing Record 506 of Set 1 | stokmarknes
# Processing Record 507 of Set 1 | cadereyta
# Processing Record 508 of Set 1 | saint-francois
# Processing Record 509 of Set 1 | imbituba
# Processing Record 510 of Set 1 | ambovombe
# Processing Record 511 of Set 1 | medvedok
# Processing Record 512 of Set 1 | bastia
# Processing Record 513 of Set 1 | hanzhong
# Processing Record 514 of Set 1 | zhezkazgan
# Processing Record 515 of Set 1 | cockburn harbour
# City not found. Skipping...
# Processing Record 516 of Set 1 | susehri
# Processing Record 517 of Set 1 | gunjur
# Processing Record 518 of Set 1 | tutoia
# Processing Record 519 of Set 1 | nha trang
# Processing Record 520 of Set 1 | podor
# Processing Record 521 of Set 1 | vanavara
# Processing Record 522 of Set 1 | tubruq
# City not found. Skipping...
# Processing Record 523 of Set 1 | tokmak
# Processing Record 524 of Set 1 | arlit
# Processing Record 525 of Set 1 | ustye
# Processing Record 526 of Set 1 | singosari
# Processing Record 527 of Set 1 | mount isa
# Processing Record 528 of Set 1 | namibe
# Processing Record 529 of Set 1 | pipri
# Processing Record 530 of Set 1 | huarmey
# Processing Record 531 of Set 1 | aranos
# Processing Record 532 of Set 1 | rome
# Processing Record 533 of Set 1 | hambantota
# Processing Record 534 of Set 1 | camocim
# Processing Record 535 of Set 1 | dhidhdhoo
# Processing Record 536 of Set 1 | jingdezhen
# Processing Record 537 of Set 1 | zhoucheng
# Processing Record 538 of Set 1 | gizo
# Processing Record 539 of Set 1 | litovko
# Processing Record 540 of Set 1 | santa maria
# Processing Record 541 of Set 1 | ust-kulom
# Processing Record 542 of Set 1 | tiarei
# Processing Record 543 of Set 1 | richards bay
# Processing Record 544 of Set 1 | calatayud
# Processing Record 545 of Set 1 | buala
# Processing Record 546 of Set 1 | smithers
# Processing Record 547 of Set 1 | sumbe
# Processing Record 548 of Set 1 | millinocket
# Processing Record 549 of Set 1 | theodoriana
# Processing Record 550 of Set 1 | mentougou
# Processing Record 551 of Set 1 | timra
# Processing Record 552 of Set 1 | mareeba
# Processing Record 553 of Set 1 | charagua
# Processing Record 554 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 555 of Set 1 | akyab
# City not found. Skipping...
# Processing Record 556 of Set 1 | camabatela
# Processing Record 557 of Set 1 | kovur
# Processing Record 558 of Set 1 | abu kamal
# Processing Record 559 of Set 1 | shakhtinsk
# Processing Record 560 of Set 1 | kuminskiy
# Processing Record 561 of Set 1 | floro
# Processing Record 562 of Set 1 | lesozavodsk
# Processing Record 563 of Set 1 | naze
# Processing Record 564 of Set 1 | kulhudhuffushi
# Processing Record 565 of Set 1 | port moresby
# Processing Record 566 of Set 1 | madarounfa
# Processing Record 567 of Set 1 | poum
# Processing Record 568 of Set 1 | coihaique
# Processing Record 569 of Set 1 | iberia
# Processing Record 570 of Set 1 | chulman
# Processing Record 571 of Set 1 | shaping
# Processing Record 572 of Set 1 | naftah
# City not found. Skipping...
# Processing Record 573 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 574 of Set 1 | baft
# Processing Record 575 of Set 1 | boras
# Processing Record 576 of Set 1 | lugoba
# Processing Record 577 of Set 1 | machali
# City not found. Skipping...
# Processing Record 578 of Set 1 | nador
# Processing Record 579 of Set 1 | fallon
# Processing Record 580 of Set 1 | teya
# Processing Record 581 of Set 1 | faxinal
# Processing Record 582 of Set 1 | mezhdurechenskiy
# Processing Record 583 of Set 1 | jurbise
# Processing Record 584 of Set 1 | atambua
# Processing Record 585 of Set 1 | antofagasta
# Processing Record 586 of Set 1 | rio brilhante
# Processing Record 587 of Set 1 | manali
# Processing Record 588 of Set 1 | simbahan
# Processing Record 589 of Set 1 | carndonagh
# Processing Record 590 of Set 1 | bam
# Processing Record 591 of Set 1 | rossland
# Processing Record 592 of Set 1 | finschhafen
# Processing Record 593 of Set 1 | gulshat
# City not found. Skipping...
# Processing Record 594 of Set 1 | turayf
# Processing Record 595 of Set 1 | lasa
# Processing Record 596 of Set 1 | hualmay
# Processing Record 597 of Set 1 | kuusamo
# Processing Record 598 of Set 1 | bud
# Processing Record 599 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 600 of Set 1 | atar
# Processing Record 601 of Set 1 | lethem
# Processing Record 602 of Set 1 | waddan
# Processing Record 603 of Set 1 | zwettl
# ---------------------
# End of Data Retrieval
# ---------------------

# %%
city_data_pd = pd.DataFrame(city_weather_final)

city_data_pd.count()
# Out:
# City          546
# Cloudiness    546
# Country       546
# Date          546
# Humidity      546
# Lat           546
# Lng           546
# Max Temp      546
# Wind Speed    546
# dtype: int64

# %%
plt.scatter(city_data_pd["Lat"], city_data_pd["Max Temp"],
            edgecolor="black", linewidths=1, marker="o",
            alpha=.8, label="Cities"
           )

plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("max Temperature")
plt.xlabel("Latitude"),
plt.grid(True)

plt.savefig("output_data/Fig1.png")
plt.show()

# %%
plt.scatter(city_data_pd["Lat"], city_data_pd["Humidity"],
            edgecolor="black", linewidths=1, marker="o",
            alpha=.8, label="Cities"
           )

plt.title("City Latitude vs. humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity")
plt.xlabel("Latitude"),
plt.grid(True)

plt.savefig("output_data/Fig2.png")
plt.show()

# %%
plt.scatter(city_data_pd["Lat"], city_data_pd["Cloudiness"],
            edgecolor="black", linewidths=1, marker="o",
            alpha=.8, label="Cities"
           )

plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness")
plt.xlabel("Latitude"),
plt.grid(True)

plt.savefig("output_data/Fig3.png")
plt.show()

# %%
plt.scatter(city_data_pd["Lat"], city_data_pd["Wind Speed"],
            edgecolor="black", linewidths=1, marker="o",
            alpha=.8, label="Cities"
           )

plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude"),
plt.grid(True)

plt.savefig("output_data/Fig4.png")
plt.show()
